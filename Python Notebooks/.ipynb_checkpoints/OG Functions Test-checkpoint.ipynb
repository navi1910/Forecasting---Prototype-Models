# %%
from Forecast_functions import *

# %%
import pandas as pd
import itertools
imports(proceed = True)

# %%
pd.read_csv('Sales Data.txt')
# Out:
#               Date  ProductCode  Plant            PlantCode Sales_Channel  \
# 0        7/10/2021      7002030   7011      Hyderabad - CFA         CP-GT
# 1        7/10/2021      7002031   7001        Ahmedabad CFA         CP-GT
# 2        7/10/2021      7002031   7012           Indore CFA         CP-GT
# 3        7/10/2021      7002031   7017          Madurai CFA         CP-GT
# 4        7/10/2021      7002032   7006        Chennai - CFA         CP-GT
# ...            ...          ...    ...                  ...           ...
# 7042847  4/13/2023      7001163   7015  Kolkata CFA (PH+AH)         AH-GT
# 7042848  4/13/2023      7001175   7009        Ghaziabad CFA         CP-GT
# 7042849  4/13/2023      7001175   7012           Indore CFA        CP-NMT
# 7042850  4/13/2023      7001175   7017          Madurai CFA         CP-GT
# 7042851  4/13/2023      7001175   7020            Patna CFA         CP-GT
#
#          Sales_Qty  Sales_Value
# 0               -3      -392.19
# ...

# %%
File_path = 'Sales Data.txt'
ProductCodes = [7000158, 7000043, 7000157, 7000022, 7003399]
plants = ['Bangalore New CFA', 'Delhi CFA', 'Zirakpur CFA']
Sales_Channels = ['CP-GT', 'RETAIL', 'CP-NMT']
models = ['arima', 'sarimax', 'rnn']

# %%
res = list(itertools.product(*[ProductCodes, plants, Sales_Channels, models]))

# %%
df1 = select_df(File_path= 'Sales Data.txt', ProductCode=7000158, PlantCode='Bangalore New CFA', Sales_Channel='CP-GT', freq='B')
# Out:
# C:\Disk D\Forecasting\Python Notebooks\Forecast_functions.py:28: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df = df.resample(freq).mean()
# C:\Users\FQ467WA\AppData\Local\anaconda3\Lib\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)

# %%
train, test = train_test_split(df1['Sales_Value'], 0.7)

# %%
test.shape
# Out:
# (202,)

# %%
orders(train, 10, 120)
# Out:
# ACF is for MA - q, PACF is for AR - p and Trend is for d - p, d, q

# %%
df1_arima = arima(train, 1, 0, 2, summary = True)
# Out:
#                                SARIMAX Results
# ...
# Dep. Variable:            Sales_Value   No. Observations:                  469
# Model:                 ARIMA(1, 0, 2)   Log Likelihood               -6073.721
# Date:                Mon, 21 Aug 2023   AIC                          12157.441
# Time:                        17:51:27   BIC                          12178.194
# Sample:                    12-02-2020   HQIC                         12165.607
#                          - 09-19-2022
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       6.989e+04   8001.121      8.735      0.000    5.42e+04    8.56e+04
# ar.L1         -0.2413      0.828     -0.292      0.771      -1.864       1.381
# ma.L1          0.6945      0.828      0.838      0.402      -0.929       2.318
# ...

# %%
# Out:
# Date
# 2022-09-20     60946.22
# 2022-09-21   -276241.28
# 2022-09-22     27443.31
# 2022-09-23     36127.89
# 2022-09-26         0.00
#                 ...
# 2023-06-22     -1500.40
# 2023-06-23     17411.37
# 2023-06-26    229721.75
# 2023-06-27     93397.12
# 2023-06-28    248522.89
# Freq: B, Name: Sales_Value, Length: 202, dtype: float64

# %%
df1_arima.forecast(202).values
# Out:
# array([54155.47899216, 69312.67723105, 70028.00615061, 69855.37092948,
#        69897.03416825, 69886.97929385, 69889.40590547, 69888.82027469,
#        69888.96160897, 69888.9274998 , 69888.9357316 , 69888.93374497,
#        69888.93422441, 69888.93410871, 69888.93413663, 69888.93412989,
#        69888.93413152, 69888.93413112, 69888.93413122, 69888.9341312 ,
#        69888.9341312 , 69888.9341312 , 69888.9341312 , 69888.9341312 ,
#        69888.9341312 , 69888.9341312 , 69888.9341312 , 69888.9341312 ,
#        69888.9341312 , 69888.9341312 , 69888.9341312 , 69888.9341312 ,
#        69888.9341312 , 69888.9341312 , 69888.9341312 , 69888.9341312 ,
#        69888.9341312 , 69888.9341312 , 69888.9341312 , 69888.9341312 ,
#        69888.9341312 , 69888.9341312 , 69888.9341312 , 69888.9341312 ,
#        69888.9341312 , 69888.9341312 , 69888.9341312 , 69888.9341312 ,
#        69888.9341312 , 69888.9341312 , 69888.9341312 , 69888.9341312 ,
# ...
